# %% [markdown]
# Этот блокнот показывает IP адрес сервера, с которого был запущен, страну и город расположения.

# %%
import json
import requests

# %%
url = 'http://ru.sxgeo.city/json/'
page = requests.get(url + '')
data = json.loads(page.text)
city = data['city']['name_en']
iso = data['country']['iso']
my_ip = data['ip']
print (my_ip + '   ' + iso + '   ' + city)
# Out:
# 35.229.215.33   US   Mountain View
